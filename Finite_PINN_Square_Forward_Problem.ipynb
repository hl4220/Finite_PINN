# %%
import os
# os.chdir(r'/content/drive/MyDrive/Work/PINN_SHM_guidedwave/WavePackge_Operater/Work_2D')
# os.chdir(r'/content/drive/MyDrive/Work/Finite_PINN/Work/Work_Sample/Square')
os.chdir(r'C:\Users\Feliz\Desktop\jupyter\Finite_PINN2')
import torch
import torch.autograd as autograd
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
import time
import scipy.io
import math
import scipy
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.parameter import Parameter
import matplotlib.pyplot as plt
import operator
from functools import reduce
from functools import partial
from timeit import default_timer
from torch.autograd import Variable
import os
import csv
from torch.autograd.functional import jacobian

# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

dim = 2

path = 'Package_Square.mat'

def derivee(y,x):
  return autograd.grad(y,x,torch.ones_like(y),retain_graph=True,create_graph=True)[0]

def som(s):
  return torch.sum(s,dim=-1,keepdim=True)
# Out:
# cuda

# %%
class Offline:
    def __init__(self, path):
        Data = scipy.io.loadmat(path)
        # Euclidean Coordinates
        coor = torch.tensor(Data['nodes'], dtype = torch.float32).to(device)
        self.X = coor[:,0:1].to(device)
        self.Y = coor[:,1:2].to(device)
        # LBO Eigenfunctions and their Derivatives
        self.Phi = torch.tensor(Data['U'], dtype = torch.float32).to(device)
        self.dPhi_dx = torch.tensor(Data['dU_dx'], dtype = torch.float32).to(device)
        self.dPhi_dy = torch.tensor(Data['dU_dy'], dtype = torch.float32).to(device)
        self.d2Phi_dx2 = torch.tensor(Data['d2U_dx2'], dtype = torch.float32).to(device)
        self.d2Phi_dy2 = torch.tensor(Data['d2U_dy2'], dtype = torch.float32).to(device)
        # Label of Nodes
        bc1_nodes = torch.tensor(Data['bc1_nodes'].astype(np.float32), dtype = torch.float32).to(device).squeeze()
        bc2_nodes = torch.tensor(Data['bc2_nodes'].astype(np.float32), dtype = torch.float32).to(device).squeeze()
        interior_nodes = torch.tensor(Data['interior_nodes'].astype(np.float32), dtype = torch.float32).to(device).squeeze()
        # Collocations of Boundary condition loss
        self.L_dbc = bc1_nodes - 1.0
        self.L_nbc = bc2_nodes - 1.0
        # Collocations of Boundary condition loss
        self.L_pde = interior_nodes - 1.0

    def forward(self, labels, n, **kwargs):
        attribute_map = {'x': ('X', True),'y': ('Y', True),
                  'phi': ('Phi', False),'dphi_dx': ('dPhi_dx', False),'dphi_dy': ('dPhi_dy', False),
                  'd2phi_dx2': ('d2Phi_dx2', False),'d2phi_dy2': ('d2Phi_dy2', False)}
        output = []
        for key, (attr, default) in attribute_map.items():
            if kwargs.get(key, default):
                output.append(getattr(self, attr)[labels.int(), :n])
        return tuple(output)

# %%
class Online:
    def __init__(self, path, off, model):
        # Database from Offline Stage
        self.off = off
        # Model of Solution
        self.model = model
        # Physics Parameters
        E, mu = 1.0, 0.3
        # Constitutives
        Cons = E/(1-mu**2)*torch.tensor([[1,mu,0],[mu,1,0],[0,0,0.5*(1-mu)]]).to(device)
        self.c1,self.c2,self.c3 = Cons[0,0],Cons[0,1],Cons[2,2]

    def label_pde(self):
        L_pde = self.off.L_pde
        return L_pde

    def Nbc_loss(self):
        x, y, du_dx, du_dy = self.off.forward(self.off.L_nbc, n_sigma, dphi_dx=True, dphi_dy=True)
        sigma_xx, sigma_xy, sigma_yx, sigma_yy, px, py = self.model.Fsigma(x,y,du_dx,du_dy)
        nbc_loss = F.mse_loss(sigma_xy, torch.zeros_like(sigma_xy)) + F.mse_loss(sigma_yy, x)
        # nbc_loss = F.mse_loss(sigma_xy, torch.zeros_like(sigma_xy)) + F.mse_loss(sigma_yy, torch.sin(x))
        return nbc_loss

    def Dbc_loss(self):
        x, y, phi = self.off.forward(self.off.L_dbc, n_u, phi=True)
        ux, uy = self.model(x, y, phi)
        dbc_loss = F.mse_loss(ux, torch.zeros_like(ux)) + F.mse_loss(uy, torch.zeros_like(uy))
        return dbc_loss

    def PDE_loss(self,label):

        x, y, dphi_dx, dphi_dy, d2phi_dx2, d2phi_dy2 = self.off.forward(label, n_sigma, dphi_dx=True, dphi_dy=True, d2phi_dx2=True, d2phi_dy2=True)
        x.requires_grad = True
        y.requires_grad = True
        sigma_xx, sigma_xy, sigma_yx, sigma_yy, px, py = self.model.Fsigma(x,y,dphi_dx,dphi_dy)

        dsigmaxx_dx = derivee(sigma_xx,x) + som(px * d2phi_dx2)
        dsigmaxy_dy = derivee(sigma_xy,y) + som(px * d2phi_dy2)
        dsigmayx_dx = derivee(sigma_yx,x) + som(py * d2phi_dx2)
        dsigmayy_dy = derivee(sigma_yy,y) + som(py * d2phi_dy2)

        pde_x = dsigmaxx_dx + dsigmaxy_dy
        pde_y = dsigmayx_dx + dsigmayy_dy

        pde_loss_x = F.mse_loss(pde_x, torch.zeros_like(pde_x))
        pde_loss_y = F.mse_loss(pde_y, torch.zeros_like(pde_y))

        return pde_loss_x + pde_loss_y

    def C_loss(self,label):

        x, y, phi, du_dx, du_dy = self.off.forward(label, n_u, phi=True, dphi_dx=True, dphi_dy=True)
        x.requires_grad = True
        y.requires_grad = True
        phi.requires_grad = True

        ux, uy = self.model(x,y,phi)

        epsilon_xx = derivee(ux,x) + som(derivee(ux,phi) * du_dx)
        epsilon_xy = derivee(ux,y) + som(derivee(ux,phi) * du_dy)
        epsilon_yx = derivee(uy,x) + som(derivee(uy,phi) * du_dx)
        epsilon_yy = derivee(uy,y) + som(derivee(uy,phi) * du_dy)

        sigma_xx0 = self.c1*epsilon_xx + self.c2*epsilon_yy
        sigma_xy0 = self.c3*epsilon_xy + self.c3*epsilon_yx
        sigma_yx0 = self.c3*epsilon_xy + self.c3*epsilon_yx
        sigma_yy0 = self.c2*epsilon_xx + self.c1*epsilon_yy

        x, y, phi, du_dx, du_dy = self.off.forward(label, n_sigma, phi=True, dphi_dx=True, dphi_dy=True)
        sigma_xx, sigma_xy, sigma_yx, sigma_yy, H1, H2 = self.model.Fsigma(x,y,du_dx,du_dy)

        loss_C = F.mse_loss(torch.cat((sigma_xx0,sigma_xy0,sigma_yx0,sigma_yy0),dim=-1), \
                    torch.cat((sigma_xx,sigma_xy,sigma_yx,sigma_yy),dim=-1))

        return loss_C

# %%
class MLP_gelu(nn.Module):
    def __init__(self,insize,outsize,width,layers):
        super().__init__()
        self.input_layer = nn.Linear(insize,width)
        self.hidden_layers = nn.ModuleList([])
        self.output_layer = nn.Linear(width,outsize)
        for i in range(layers):
          self.linear_layer = nn.Linear(width,width)
          self.hidden_layers.append(self.linear_layer)
        self.layers = layers

    def forward(self, x): # F.gelu
        layer_out = F.gelu(self.input_layer(x))
        for i in range(self.layers):
            layer_out = F.gelu(self.hidden_layers[i](layer_out))
        layer_out = self.output_layer(layer_out)
        return layer_out

class Finite_PINN(nn.Module):
    def __init__(self, n_sigma, n_u):
        super(Finite_PINN, self).__init__()

        width = 128
        self.NN_H1 = MLP_gelu(2,n_sigma,width,4)
        self.NN_H2 = MLP_gelu(2,n_sigma,width,4)
        self.NN_eu1 = MLP_gelu(2+n_u,1,width,4)
        self.NN_eu2 = MLP_gelu(2+n_u,1,width,4)

    def forward(self, x, y, u):

        v1 = self.NN_eu1(torch.cat((x,y,u),dim=-1))
        v2 = self.NN_eu2(torch.cat((x,y,u),dim=-1))

        return v1,v2

    def Fsigma(self, x, y, du_dx, du_dy):

        px = self.NN_H1(torch.cat((x,y),dim=-1))
        py = self.NN_H2(torch.cat((x,y),dim=-1))

        sig_xx, sig_xy = som(px * du_dx), som(px * du_dy)
        sig_yx, sig_yy = som(py * du_dx), som(py * du_dy)

        return sig_xx,sig_xy,sig_yx,sig_yy,px,py

# %%
n_sigma = 4
n_u = 4

OFF = Offline(path)
model = Finite_PINN(n_sigma = n_sigma, n_u = n_u).to(device, dtype = torch.float32)
ON = Online(path,OFF,model)

L_pde = ON.label_pde()
dataset = torch.utils.data.TensorDataset(L_pde,torch.zeros_like(L_pde))
trainset = torch.utils.data.DataLoader(dataset, batch_size=200, shuffle=True, drop_last=True)

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
num_epochs = 1000
csize = 4

for ep in range(num_epochs):
    model.train()
    t1 = default_timer()
    bc_mse,pde_mse,c_mse = 0,0,0
    ne = 0

    for l_pde, r_pde in trainset:

        ne += 1
        optimizer.zero_grad()

        # Boundary Condition Loss
        dbc_loss = ON.Dbc_loss()
        nbc_loss = ON.Nbc_loss()
        # PDE Loss
        pde_loss = ON.PDE_loss(l_pde)
        # Constitutive loss
        C_loss = ON.C_loss(l_pde)

        Loss = dbc_loss + nbc_loss + pde_loss + C_loss

        Loss.backward()
        optimizer.step()

        bc_mse += dbc_loss.item() + nbc_loss.item()
        pde_mse += pde_loss.item()
        c_mse += C_loss.item()

    bc_mse /= ne
    pde_mse /= ne
    c_mse /= ne

    t2 = default_timer()

    print(f'Epoch:{ep+1}, Time:{t2-t1:.3g}s, BC Loss:{bc_mse:.3e}, PDE Loss:{pde_mse:.3e}, C Loss:{c_mse:.3e}')
# Out:
# Epoch:1, Time:1.59s, BC Loss:2.578e-01, PDE Loss:4.345e-02, C Loss:6.233e-04
# Epoch:2, Time:1.41s, BC Loss:2.062e-01, PDE Loss:5.365e-02, C Loss:4.429e-04
# Epoch:3, Time:1.45s, BC Loss:1.747e-01, PDE Loss:5.962e-02, C Loss:1.752e-04
# Epoch:4, Time:1.46s, BC Loss:1.186e-01, PDE Loss:5.801e-02, C Loss:4.136e-04
# Epoch:61, Time:1.37s, BC Loss:1.918e-04, PDE Loss:1.282e-03, C Loss:5.584e-04
# Epoch:62, Time:1.48s, BC Loss:1.865e-04, PDE Loss:1.197e-03, C Loss:5.520e-04
# Epoch:63, Time:1.43s, BC Loss:1.865e-04, PDE Loss:1.237e-03, C Loss:5.457e-04
# Epoch:64, Time:1.39s, BC Loss:1.864e-04, PDE Loss:1.225e-03, C Loss:5.440e-04
# Epoch:65, Time:1.45s, BC Loss:1.717e-04, PDE Loss:1.156e-03, C Loss:5.349e-04
# Epoch:66, Time:1.44s, BC Loss:1.733e-04, PDE Loss:1.204e-03, C Loss:5.320e-04
# Epoch:67, Time:1.44s, BC Loss:1.795e-04, PDE Loss:1.150e-03, C Loss:5.251e-04
# Epoch:68, Time:1.55s, BC Loss:1.800e-04, PDE Loss:1.155e-03, C Loss:5.219e-04
# Epoch:69, Time:1.37s, BC Loss:1.661e-04, PDE Loss:1.064e-03, C Loss:5.160e-04
# Epoch:70, Time:1.46s, BC Loss:1.637e-04, PDE Loss:1.041e-03, C Loss:5.110e-04
# Epoch:71, Time:1.47s, BC Loss:1.662e-04, PDE Loss:1.062e-03, C Loss:5.068e-04
# Epoch:72, Time:1.32s, BC Loss:1.597e-04, PDE Loss:1.018e-03, C Loss:5.026e-04
# Epoch:73, Time:1.32s, BC Loss:1.610e-04, PDE Loss:1.042e-03, C Loss:4.988e-04
# Epoch:74, Time:1.33s, BC Loss:1.732e-04, PDE Loss:1.080e-03, C Loss:4.937e-04
# Epoch:75, Time:1.37s, BC Loss:1.566e-04, PDE Loss:9.618e-04, C Loss:4.880e-04
# Epoch:76, Time:1.46s, BC Loss:1.485e-04, PDE Loss:9.085e-04, C Loss:4.844e-04
# Epoch:77, Time:1.36s, BC Loss:1.561e-04, PDE Loss:9.868e-04, C Loss:4.821e-04
# Epoch:78, Time:1.4s, BC Loss:1.584e-04, PDE Loss:9.805e-04, C Loss:4.766e-04
# Epoch:79, Time:1.36s, BC Loss:1.632e-04, PDE Loss:1.020e-03, C Loss:4.767e-04
# Epoch:80, Time:1.39s, BC Loss:1.561e-04, PDE Loss:9.691e-04, C Loss:4.704e-04
# Epoch:81, Time:1.54s, BC Loss:1.589e-04, PDE Loss:9.866e-04, C Loss:4.653e-04
# Epoch:82, Time:1.42s, BC Loss:1.533e-04, PDE Loss:9.633e-04, C Loss:4.654e-04
# Epoch:83, Time:1.42s, BC Loss:1.484e-04, PDE Loss:8.907e-04, C Loss:4.598e-04
# Epoch:84, Time:1.41s, BC Loss:1.496e-04, PDE Loss:9.343e-04, C Loss:4.579e-04
# Epoch:85, Time:1.35s, BC Loss:1.565e-04, PDE Loss:9.176e-04, C Loss:4.541e-04
# Epoch:86, Time:1.39s, BC Loss:1.386e-04, PDE Loss:8.331e-04, C Loss:4.501e-04
# Epoch:87, Time:1.39s, BC Loss:1.415e-04, PDE Loss:8.500e-04, C Loss:4.453e-04
# Epoch:88, Time:1.37s, BC Loss:1.406e-04, PDE Loss:8.160e-04, C Loss:4.397e-04
# Epoch:89, Time:1.4s, BC Loss:1.346e-04, PDE Loss:7.834e-04, C Loss:4.382e-04
# Epoch:90, Time:1.32s, BC Loss:1.369e-04, PDE Loss:9.032e-04, C Loss:4.377e-04
# Epoch:91, Time:1.32s, BC Loss:1.354e-04, PDE Loss:8.032e-04, C Loss:4.336e-04
# Epoch:92, Time:1.35s, BC Loss:1.302e-04, PDE Loss:7.706e-04, C Loss:4.297e-04
# Epoch:93, Time:1.37s, BC Loss:1.530e-04, PDE Loss:8.956e-04, C Loss:4.277e-04
# Epoch:94, Time:1.33s, BC Loss:1.365e-04, PDE Loss:7.590e-04, C Loss:4.254e-04
# Epoch:95, Time:1.4s, BC Loss:1.293e-04, PDE Loss:7.201e-04, C Loss:4.209e-04
# Epoch:96, Time:1.31s, BC Loss:1.291e-04, PDE Loss:7.142e-04, C Loss:4.188e-04
# Epoch:97, Time:1.34s, BC Loss:1.309e-04, PDE Loss:7.125e-04, C Loss:4.129e-04
# Epoch:98, Time:1.37s, BC Loss:1.242e-04, PDE Loss:7.006e-04, C Loss:4.123e-04
# Epoch:99, Time:1.41s, BC Loss:1.248e-04, PDE Loss:7.216e-04, C Loss:4.077e-04
# Epoch:100, Time:1.39s, BC Loss:1.225e-04, PDE Loss:6.678e-04, C Loss:4.076e-04
# Epoch:101, Time:1.38s, BC Loss:1.238e-04, PDE Loss:7.432e-04, C Loss:4.033e-04
# Epoch:102, Time:1.35s, BC Loss:1.266e-04, PDE Loss:7.190e-04, C Loss:4.019e-04
# Epoch:103, Time:1.35s, BC Loss:1.277e-04, PDE Loss:7.092e-04, C Loss:3.975e-04
# Epoch:104, Time:1.58s, BC Loss:1.195e-04, PDE Loss:6.402e-04, C Loss:3.938e-04
# Epoch:105, Time:1.3s, BC Loss:1.188e-04, PDE Loss:6.559e-04, C Loss:3.900e-04
# Epoch:106, Time:1.27s, BC Loss:1.199e-04, PDE Loss:6.546e-04, C Loss:3.890e-04
# Epoch:107, Time:1.29s, BC Loss:1.236e-04, PDE Loss:6.525e-04, C Loss:3.850e-04
# Epoch:108, Time:1.29s, BC Loss:1.116e-04, PDE Loss:5.838e-04, C Loss:3.838e-04
# Epoch:109, Time:1.33s, BC Loss:1.171e-04, PDE Loss:6.277e-04, C Loss:3.810e-04
# Epoch:110, Time:1.3s, BC Loss:1.173e-04, PDE Loss:6.864e-04, C Loss:3.789e-04
# Epoch:111, Time:1.31s, BC Loss:1.148e-04, PDE Loss:6.398e-04, C Loss:3.735e-04
# Epoch:112, Time:1.31s, BC Loss:1.243e-04, PDE Loss:7.012e-04, C Loss:3.709e-04
# Epoch:113, Time:1.33s, BC Loss:1.100e-04, PDE Loss:5.549e-04, C Loss:3.670e-04
# Epoch:114, Time:1.34s, BC Loss:1.068e-04, PDE Loss:5.871e-04, C Loss:3.656e-04
# Epoch:115, Time:1.38s, BC Loss:1.189e-04, PDE Loss:6.566e-04, C Loss:3.614e-04
# Epoch:116, Time:1.36s, BC Loss:1.050e-04, PDE Loss:5.363e-04, C Loss:3.591e-04
# Epoch:117, Time:1.35s, BC Loss:1.071e-04, PDE Loss:5.696e-04, C Loss:3.555e-04
# Epoch:118, Time:1.3s, BC Loss:1.051e-04, PDE Loss:5.465e-04, C Loss:3.532e-04
# Epoch:119, Time:1.39s, BC Loss:1.053e-04, PDE Loss:5.522e-04, C Loss:3.483e-04
# Epoch:120, Time:1.43s, BC Loss:1.025e-04, PDE Loss:5.437e-04, C Loss:3.451e-04
# Epoch:121, Time:1.37s, BC Loss:1.017e-04, PDE Loss:5.229e-04, C Loss:3.405e-04
# Epoch:122, Time:1.34s, BC Loss:9.935e-05, PDE Loss:5.341e-04, C Loss:3.385e-04
# Epoch:123, Time:1.3s, BC Loss:9.618e-05, PDE Loss:4.996e-04, C Loss:3.356e-04
# Epoch:124, Time:1.36s, BC Loss:1.061e-04, PDE Loss:5.831e-04, C Loss:3.335e-04
# Epoch:125, Time:1.28s, BC Loss:1.034e-04, PDE Loss:5.499e-04, C Loss:3.310e-04
# Epoch:126, Time:1.27s, BC Loss:9.444e-05, PDE Loss:4.564e-04, C Loss:3.253e-04
# Epoch:127, Time:1.24s, BC Loss:9.459e-05, PDE Loss:4.791e-04, C Loss:3.237e-04
# Epoch:128, Time:1.21s, BC Loss:9.620e-05, PDE Loss:4.892e-04, C Loss:3.194e-04
# Epoch:129, Time:1.2s, BC Loss:9.273e-05, PDE Loss:4.774e-04, C Loss:3.157e-04
# Epoch:130, Time:1.21s, BC Loss:9.529e-05, PDE Loss:4.905e-04, C Loss:3.117e-04
# Epoch:131, Time:1.37s, BC Loss:9.377e-05, PDE Loss:4.802e-04, C Loss:3.099e-04
# Epoch:132, Time:1.4s, BC Loss:9.369e-05, PDE Loss:4.716e-04, C Loss:3.066e-04
# Epoch:133, Time:1.34s, BC Loss:9.484e-05, PDE Loss:5.230e-04, C Loss:3.054e-04
# Epoch:134, Time:1.43s, BC Loss:8.956e-05, PDE Loss:4.222e-04, C Loss:2.984e-04
# Epoch:135, Time:1.36s, BC Loss:8.769e-05, PDE Loss:4.342e-04, C Loss:2.951e-04
# Epoch:136, Time:1.4s, BC Loss:8.582e-05, PDE Loss:4.249e-04, C Loss:2.931e-04
# Epoch:137, Time:1.33s, BC Loss:8.615e-05, PDE Loss:4.218e-04, C Loss:2.872e-04
# Epoch:138, Time:1.3s, BC Loss:8.563e-05, PDE Loss:4.191e-04, C Loss:2.836e-04
# Epoch:139, Time:1.25s, BC Loss:8.222e-05, PDE Loss:3.972e-04, C Loss:2.814e-04
# Epoch:140, Time:1.35s, BC Loss:8.742e-05, PDE Loss:4.608e-04, C Loss:2.797e-04
# Epoch:141, Time:1.32s, BC Loss:8.233e-05, PDE Loss:4.278e-04, C Loss:2.740e-04
# Epoch:142, Time:1.26s, BC Loss:9.164e-05, PDE Loss:5.163e-04, C Loss:2.724e-04
# Epoch:143, Time:1.3s, BC Loss:1.002e-04, PDE Loss:5.334e-04, C Loss:2.725e-04
# Epoch:144, Time:1.25s, BC Loss:8.579e-05, PDE Loss:4.381e-04, C Loss:2.668e-04
# Epoch:145, Time:1.29s, BC Loss:8.803e-05, PDE Loss:4.532e-04, C Loss:2.630e-04
# Epoch:146, Time:1.28s, BC Loss:7.870e-05, PDE Loss:3.847e-04, C Loss:2.585e-04
# Epoch:147, Time:1.23s, BC Loss:7.752e-05, PDE Loss:3.762e-04, C Loss:2.577e-04
# Epoch:148, Time:1.3s, BC Loss:8.132e-05, PDE Loss:3.666e-04, C Loss:2.535e-04
# Epoch:149, Time:1.38s, BC Loss:7.528e-05, PDE Loss:3.341e-04, C Loss:2.511e-04
# Epoch:150, Time:1.53s, BC Loss:7.479e-05, PDE Loss:3.222e-04, C Loss:2.482e-04
# Epoch:151, Time:1.44s, BC Loss:7.611e-05, PDE Loss:3.354e-04, C Loss:2.436e-04
# Epoch:152, Time:1.41s, BC Loss:7.655e-05, PDE Loss:3.644e-04, C Loss:2.417e-04
# Epoch:153, Time:1.36s, BC Loss:7.539e-05, PDE Loss:3.393e-04, C Loss:2.397e-04
# Epoch:154, Time:1.32s, BC Loss:7.873e-05, PDE Loss:3.803e-04, C Loss:2.363e-04
# Epoch:155, Time:1.28s, BC Loss:7.387e-05, PDE Loss:3.230e-04, C Loss:2.336e-04
# Epoch:156, Time:1.22s, BC Loss:7.826e-05, PDE Loss:3.555e-04, C Loss:2.322e-04
# Epoch:157, Time:1.29s, BC Loss:7.054e-05, PDE Loss:3.009e-04, C Loss:2.275e-04
# Epoch:158, Time:1.39s, BC Loss:7.257e-05, PDE Loss:3.089e-04, C Loss:2.251e-04
# Epoch:159, Time:1.36s, BC Loss:7.482e-05, PDE Loss:3.139e-04, C Loss:2.232e-04
# Epoch:160, Time:1.41s, BC Loss:7.075e-05, PDE Loss:3.246e-04, C Loss:2.216e-04
# Epoch:161, Time:1.37s, BC Loss:7.096e-05, PDE Loss:2.718e-04, C Loss:2.181e-04
# Epoch:162, Time:1.23s, BC Loss:6.914e-05, PDE Loss:3.014e-04, C Loss:2.137e-04
# Epoch:163, Time:1.21s, BC Loss:7.060e-05, PDE Loss:2.700e-04, C Loss:2.131e-04
# Epoch:164, Time:1.46s, BC Loss:7.173e-05, PDE Loss:3.024e-04, C Loss:2.112e-04
# Epoch:165, Time:1.42s, BC Loss:7.951e-05, PDE Loss:4.100e-04, C Loss:2.101e-04
# Epoch:166, Time:1.46s, BC Loss:7.029e-05, PDE Loss:2.842e-04, C Loss:2.059e-04
# Epoch:167, Time:1.49s, BC Loss:6.655e-05, PDE Loss:2.532e-04, C Loss:2.033e-04
# Epoch:168, Time:1.42s, BC Loss:6.688e-05, PDE Loss:2.486e-04, C Loss:1.991e-04
# Epoch:169, Time:1.59s, BC Loss:6.639e-05, PDE Loss:2.452e-04, C Loss:1.986e-04
# Epoch:170, Time:1.46s, BC Loss:6.694e-05, PDE Loss:2.609e-04, C Loss:1.959e-04
# Epoch:171, Time:1.38s, BC Loss:6.636e-05, PDE Loss:2.418e-04, C Loss:1.945e-04
# Epoch:172, Time:1.32s, BC Loss:8.513e-05, PDE Loss:4.797e-04, C Loss:1.947e-04
# Epoch:173, Time:1.27s, BC Loss:7.189e-05, PDE Loss:3.449e-04, C Loss:1.932e-04
# Epoch:202, Time:1.48s, BC Loss:6.226e-05, PDE Loss:1.958e-04, C Loss:1.493e-04
# Epoch:203, Time:1.33s, BC Loss:6.497e-05, PDE Loss:2.485e-04, C Loss:1.498e-04
# Epoch:204, Time:1.26s, BC Loss:6.080e-05, PDE Loss:1.783e-04, C Loss:1.478e-04
# Epoch:205, Time:1.24s, BC Loss:5.962e-05, PDE Loss:1.861e-04, C Loss:1.460e-04
# Epoch:206, Time:1.2s, BC Loss:6.374e-05, PDE Loss:1.933e-04, C Loss:1.484e-04
# Epoch:207, Time:1.44s, BC Loss:6.885e-05, PDE Loss:2.550e-04, C Loss:1.439e-04
# Epoch:208, Time:1.32s, BC Loss:6.256e-05, PDE Loss:2.294e-04, C Loss:1.437e-04
# Epoch:209, Time:1.45s, BC Loss:5.992e-05, PDE Loss:1.716e-04, C Loss:1.428e-04
# Epoch:210, Time:1.29s, BC Loss:5.923e-05, PDE Loss:1.634e-04, C Loss:1.416e-04
# Epoch:211, Time:1.29s, BC Loss:6.261e-05, PDE Loss:2.392e-04, C Loss:1.420e-04
# Epoch:212, Time:1.34s, BC Loss:6.049e-05, PDE Loss:1.739e-04, C Loss:1.406e-04
# Epoch:213, Time:1.36s, BC Loss:6.089e-05, PDE Loss:1.683e-04, C Loss:1.401e-04
# Epoch:214, Time:1.34s, BC Loss:5.874e-05, PDE Loss:1.557e-04, C Loss:1.369e-04
# Epoch:215, Time:1.3s, BC Loss:5.900e-05, PDE Loss:1.739e-04, C Loss:1.358e-04
# Epoch:216, Time:1.38s, BC Loss:5.846e-05, PDE Loss:1.803e-04, C Loss:1.350e-04
# Epoch:217, Time:1.4s, BC Loss:7.075e-05, PDE Loss:2.890e-04, C Loss:1.352e-04
# Epoch:218, Time:1.4s, BC Loss:6.064e-05, PDE Loss:1.768e-04, C Loss:1.346e-04
# Epoch:219, Time:1.42s, BC Loss:6.316e-05, PDE Loss:2.044e-04, C Loss:1.342e-04
# Epoch:220, Time:1.42s, BC Loss:6.210e-05, PDE Loss:2.264e-04, C Loss:1.328e-04
# Epoch:221, Time:1.26s, BC Loss:5.974e-05, PDE Loss:1.851e-04, C Loss:1.310e-04
# Epoch:222, Time:1.22s, BC Loss:7.399e-05, PDE Loss:4.831e-04, C Loss:1.339e-04
# Epoch:223, Time:1.22s, BC Loss:6.054e-05, PDE Loss:1.893e-04, C Loss:1.320e-04
# Epoch:224, Time:1.27s, BC Loss:5.844e-05, PDE Loss:1.718e-04, C Loss:1.285e-04
# Epoch:225, Time:1.78s, BC Loss:5.610e-05, PDE Loss:1.528e-04, C Loss:1.286e-04
# Epoch:226, Time:1.82s, BC Loss:5.748e-05, PDE Loss:1.545e-04, C Loss:1.276e-04
# Epoch:227, Time:1.58s, BC Loss:5.681e-05, PDE Loss:1.458e-04, C Loss:1.274e-04
# Epoch:228, Time:1.33s, BC Loss:5.719e-05, PDE Loss:1.448e-04, C Loss:1.267e-04
# Epoch:229, Time:1.31s, BC Loss:5.772e-05, PDE Loss:1.454e-04, C Loss:1.258e-04
# Epoch:230, Time:1.49s, BC Loss:5.994e-05, PDE Loss:1.741e-04, C Loss:1.235e-04
# Epoch:231, Time:1.31s, BC Loss:5.736e-05, PDE Loss:1.570e-04, C Loss:1.229e-04
# Epoch:232, Time:1.33s, BC Loss:5.570e-05, PDE Loss:1.434e-04, C Loss:1.230e-04
# Epoch:233, Time:1.41s, BC Loss:5.553e-05, PDE Loss:1.565e-04, C Loss:1.210e-04
# Epoch:234, Time:1.55s, BC Loss:5.639e-05, PDE Loss:1.335e-04, C Loss:1.198e-04
# Epoch:235, Time:1.32s, BC Loss:5.716e-05, PDE Loss:1.659e-04, C Loss:1.195e-04
# Epoch:236, Time:1.21s, BC Loss:5.466e-05, PDE Loss:1.632e-04, C Loss:1.192e-04
# Epoch:237, Time:1.23s, BC Loss:5.749e-05, PDE Loss:1.808e-04, C Loss:1.182e-04
# Epoch:238, Time:1.28s, BC Loss:5.905e-05, PDE Loss:2.280e-04, C Loss:1.186e-04
# Epoch:239, Time:1.32s, BC Loss:6.117e-05, PDE Loss:2.316e-04, C Loss:1.168e-04
# Epoch:240, Time:1.3s, BC Loss:5.986e-05, PDE Loss:1.986e-04, C Loss:1.169e-04
# Epoch:241, Time:1.51s, BC Loss:5.447e-05, PDE Loss:1.399e-04, C Loss:1.152e-04
# Epoch:242, Time:1.34s, BC Loss:5.609e-05, PDE Loss:1.577e-04, C Loss:1.162e-04
# Epoch:243, Time:1.26s, BC Loss:5.551e-05, PDE Loss:1.667e-04, C Loss:1.150e-04
# Epoch:244, Time:1.33s, BC Loss:5.468e-05, PDE Loss:1.454e-04, C Loss:1.141e-04
# Epoch:245, Time:1.33s, BC Loss:5.796e-05, PDE Loss:1.601e-04, C Loss:1.155e-04
# Epoch:246, Time:1.41s, BC Loss:5.365e-05, PDE Loss:1.281e-04, C Loss:1.125e-04
# Epoch:247, Time:1.38s, BC Loss:5.499e-05, PDE Loss:1.629e-04, C Loss:1.116e-04
# Epoch:248, Time:1.41s, BC Loss:5.723e-05, PDE Loss:1.852e-04, C Loss:1.117e-04
# Epoch:249, Time:1.34s, BC Loss:5.592e-05, PDE Loss:1.612e-04, C Loss:1.118e-04
# Epoch:250, Time:1.32s, BC Loss:5.409e-05, PDE Loss:1.479e-04, C Loss:1.106e-04
# Epoch:251, Time:1.36s, BC Loss:5.298e-05, PDE Loss:1.346e-04, C Loss:1.089e-04
# Epoch:252, Time:1.22s, BC Loss:5.749e-05, PDE Loss:1.779e-04, C Loss:1.108e-04
# Epoch:253, Time:1.21s, BC Loss:5.746e-05, PDE Loss:1.519e-04, C Loss:1.111e-04
# Epoch:254, Time:1.2s, BC Loss:5.313e-05, PDE Loss:1.237e-04, C Loss:1.072e-04
# Epoch:255, Time:1.29s, BC Loss:5.290e-05, PDE Loss:1.317e-04, C Loss:1.069e-04
# Epoch:256, Time:1.36s, BC Loss:5.403e-05, PDE Loss:1.420e-04, C Loss:1.056e-04
# Epoch:257, Time:1.5s, BC Loss:5.315e-05, PDE Loss:1.360e-04, C Loss:1.056e-04
# Epoch:539, Time:1.49s, BC Loss:4.413e-05, PDE Loss:1.040e-04, C Loss:5.873e-05
# Epoch:540, Time:1.39s, BC Loss:4.456e-05, PDE Loss:1.178e-04, C Loss:6.159e-05
# Epoch:541, Time:1.46s, BC Loss:4.319e-05, PDE Loss:1.037e-04, C Loss:6.079e-05
# Epoch:542, Time:1.33s, BC Loss:4.259e-05, PDE Loss:1.018e-04, C Loss:5.929e-05
# Epoch:543, Time:1.21s, BC Loss:4.217e-05, PDE Loss:7.039e-05, C Loss:5.932e-05
# Epoch:544, Time:1.23s, BC Loss:4.077e-05, PDE Loss:7.697e-05, C Loss:5.944e-05
# Epoch:545, Time:1.28s, BC Loss:4.261e-05, PDE Loss:7.641e-05, C Loss:5.921e-05
# Epoch:546, Time:1.4s, BC Loss:4.175e-05, PDE Loss:7.947e-05, C Loss:5.937e-05
# Epoch:547, Time:1.35s, BC Loss:4.268e-05, PDE Loss:1.173e-04, C Loss:5.914e-05
# Epoch:548, Time:1.19s, BC Loss:4.234e-05, PDE Loss:1.154e-04, C Loss:5.953e-05
# Epoch:549, Time:1.35s, BC Loss:4.220e-05, PDE Loss:8.261e-05, C Loss:5.994e-05
# Epoch:550, Time:1.53s, BC Loss:4.873e-05, PDE Loss:1.424e-04, C Loss:5.993e-05
# Epoch:551, Time:1.36s, BC Loss:4.195e-05, PDE Loss:8.486e-05, C Loss:5.906e-05
# Epoch:552, Time:1.29s, BC Loss:4.112e-05, PDE Loss:9.241e-05, C Loss:5.871e-05
# Epoch:553, Time:1.39s, BC Loss:4.335e-05, PDE Loss:9.444e-05, C Loss:5.927e-05
# Epoch:554, Time:1.47s, BC Loss:4.254e-05, PDE Loss:9.328e-05, C Loss:5.894e-05
# Epoch:555, Time:1.52s, BC Loss:4.090e-05, PDE Loss:7.436e-05, C Loss:5.758e-05
# Epoch:556, Time:1.38s, BC Loss:4.283e-05, PDE Loss:7.163e-05, C Loss:6.007e-05
# Epoch:557, Time:1.32s, BC Loss:4.187e-05, PDE Loss:8.034e-05, C Loss:5.888e-05
# Epoch:558, Time:1.27s, BC Loss:4.376e-05, PDE Loss:1.115e-04, C Loss:5.980e-05
# Epoch:559, Time:1.29s, BC Loss:4.104e-05, PDE Loss:7.618e-05, C Loss:5.791e-05
# Epoch:560, Time:1.35s, BC Loss:4.088e-05, PDE Loss:7.741e-05, C Loss:5.883e-05
# Epoch:561, Time:1.34s, BC Loss:4.343e-05, PDE Loss:8.453e-05, C Loss:5.881e-05
# Epoch:562, Time:1.2s, BC Loss:4.058e-05, PDE Loss:8.712e-05, C Loss:5.789e-05
# Epoch:563, Time:1.41s, BC Loss:4.101e-05, PDE Loss:7.185e-05, C Loss:5.840e-05
# Epoch:564, Time:1.46s, BC Loss:4.113e-05, PDE Loss:9.630e-05, C Loss:5.896e-05
# Epoch:565, Time:1.35s, BC Loss:4.363e-05, PDE Loss:1.055e-04, C Loss:5.791e-05
# Epoch:566, Time:1.38s, BC Loss:4.261e-05, PDE Loss:1.270e-04, C Loss:5.758e-05
# Epoch:982, Time:1.27s, BC Loss:3.397e-05, PDE Loss:5.144e-05, C Loss:4.747e-05
# Epoch:983, Time:1.24s, BC Loss:3.421e-05, PDE Loss:5.734e-05, C Loss:4.696e-05
# Epoch:984, Time:1.25s, BC Loss:3.550e-05, PDE Loss:6.916e-05, C Loss:4.773e-05
# Epoch:985, Time:1.2s, BC Loss:3.536e-05, PDE Loss:7.484e-05, C Loss:4.761e-05
# Epoch:986, Time:1.19s, BC Loss:3.458e-05, PDE Loss:5.286e-05, C Loss:4.817e-05
# Epoch:987, Time:1.37s, BC Loss:3.583e-05, PDE Loss:6.617e-05, C Loss:4.832e-05
# Epoch:988, Time:1.32s, BC Loss:3.306e-05, PDE Loss:4.971e-05, C Loss:4.680e-05
# Epoch:989, Time:1.3s, BC Loss:3.381e-05, PDE Loss:6.989e-05, C Loss:4.720e-05
# Epoch:990, Time:1.35s, BC Loss:3.486e-05, PDE Loss:6.021e-05, C Loss:4.752e-05
# Epoch:991, Time:1.31s, BC Loss:3.439e-05, PDE Loss:6.078e-05, C Loss:4.603e-05
# Epoch:992, Time:1.34s, BC Loss:3.487e-05, PDE Loss:5.266e-05, C Loss:4.722e-05
# Epoch:993, Time:1.3s, BC Loss:3.923e-05, PDE Loss:9.923e-05, C Loss:4.801e-05
# Epoch:994, Time:1.29s, BC Loss:3.799e-05, PDE Loss:9.544e-05, C Loss:4.783e-05
# Epoch:995, Time:1.28s, BC Loss:3.597e-05, PDE Loss:6.451e-05, C Loss:4.661e-05
# Epoch:996, Time:1.34s, BC Loss:3.368e-05, PDE Loss:6.871e-05, C Loss:4.832e-05
# Epoch:997, Time:1.37s, BC Loss:3.642e-05, PDE Loss:7.467e-05, C Loss:4.759e-05
# Epoch:998, Time:1.4s, BC Loss:3.404e-05, PDE Loss:5.534e-05, C Loss:4.719e-05
# Epoch:999, Time:1.27s, BC Loss:3.468e-05, PDE Loss:6.638e-05, C Loss:4.698e-05
# Epoch:1000, Time:1.21s, BC Loss:3.377e-05, PDE Loss:5.462e-05, C Loss:4.597e-05

# %%
model.eval()
X_plot, Y_plot, Phi_plot = OFF.X, OFF.Y, OFF.Phi[:,:n_u]
vx_plot, vy_plot = model(OFF.X, OFF.Y, OFF.Phi[:,:n_u])
vx_plot = vx_plot.squeeze().squeeze().detach().cpu()
vy_plot = vy_plot.squeeze().squeeze().detach().cpu()
plt.figure(figsize=(6, 5))
plt.subplot(2, 2, 1)
plt.scatter(X_plot.squeeze().detach().cpu(), Y_plot.squeeze().detach().cpu(), c=vx_plot, s = 1.5, cmap='jet')
plt.title('Ux')
plt.axis('equal')
plt.axis('off')
plt.colorbar(fraction=0.046, pad=0.04)
plt.subplot(2, 2, 2)
plt.scatter(X_plot.squeeze().detach().cpu(), Y_plot.squeeze().detach().cpu(), c=vy_plot, s = 1.5, cmap='jet')
plt.title('Uy')
plt.axis('equal')
plt.axis('off')
plt.colorbar(fraction=0.046, pad=0.04)
plt.savefig('square.png')
plt.tight_layout()
plt.show()
