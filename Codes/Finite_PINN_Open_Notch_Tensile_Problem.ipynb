# %%
import os
os.chdir(r'path')
import torch
import torch.autograd as autograd
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
import time
import scipy.io
import math
import scipy
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.parameter import Parameter
import matplotlib.pyplot as plt
import operator
from functools import reduce
from functools import partial
from timeit import default_timer
from torch.autograd import Variable
import os
import csv
from torch.autograd.functional import jacobian

# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

path = 'Package_Open_Notch.mat'

def derivee(y,x):
  return autograd.grad(y,x,torch.ones_like(y),retain_graph=True,create_graph=True)[0]

def som(s):
  return torch.sum(s,dim=-1,keepdim=True)
# Out:
# cuda

# %%
class Offline:
    def __init__(self, path):
        Data = scipy.io.loadmat(path)
        # Euclidean Coordinates
        coor = torch.tensor(Data['nodes'], dtype = torch.float32).to(device)
        self.X = coor[:,0:1].to(device)
        self.Y = coor[:,1:2].to(device)
        # LBO Eigenfunctions and their Derivatives
        self.Phi = torch.tensor(Data['phi'], dtype = torch.float32).to(device)
        self.dPhi_dx = torch.tensor(Data['dphi_dx'], dtype = torch.float32).to(device)
        self.dPhi_dy = torch.tensor(Data['dphi_dy'], dtype = torch.float32).to(device)
        self.d2Phi_dx2 = torch.tensor(Data['d2phi_dx2'], dtype = torch.float32).to(device)
        self.d2Phi_dy2 = torch.tensor(Data['d2phi_dy2'], dtype = torch.float32).to(device)
        # Label of Nodes
        bc1_nodes = torch.tensor(Data['bc1_nodes'].astype(np.float32), dtype = torch.float32).to(device).squeeze()
        bc2_nodes = torch.tensor(Data['bc2_nodes'].astype(np.float32), dtype = torch.float32).to(device).squeeze()
        interior_nodes = torch.tensor(Data['interior_nodes'].astype(np.float32), dtype = torch.float32).to(device).squeeze()
        # Collocations of Boundary condition loss
        self.L_dbc = bc1_nodes - 1.0
        self.L_nbc = bc2_nodes - 1.0
        # Collocations of Boundary condition loss
        self.L_pde = interior_nodes - 1.0

    def forward(self, labels, n, **kwargs):
        attribute_map = {'x': ('X', True),'y': ('Y', True),
                  'phi': ('Phi', False),'dphi_dx': ('dPhi_dx', False),'dphi_dy': ('dPhi_dy', False),
                  'd2phi_dx2': ('d2Phi_dx2', False),'d2phi_dy2': ('d2Phi_dy2', False)}
        output = []
        for key, (attr, default) in attribute_map.items():
            if kwargs.get(key, default):
                output.append(getattr(self, attr)[labels.int(), :n])
        return tuple(output)

# %%
class Online:
    def __init__(self, path, off, model):
        # Database from Offline Stage
        self.off = off
        # Model of Solution
        self.model = model
        # Physics Parameters
        E, mu = 1.0, 0.3
        # Constitutives
        Cons = E/(1-mu**2)*torch.tensor([[1,mu,0],[mu,1,0],[0,0,0.5*(1-mu)]]).to(device)
        self.c1,self.c2,self.c3 = Cons[0,0],Cons[0,1],Cons[2,2]
        # Supervised Data
        Data = scipy.io.loadmat(path)
        self.L_data = torch.tensor(Data['L_label'].astype(np.float32), dtype = torch.float32).to(device) - 1.0
        self.U_data = torch.tensor(Data['U_label'], dtype = torch.float32).to(device)

    def label_pde(self):
        L_pde = self.off.L_pde
        return L_pde

    def Data_loss(self):
        x, y, phi, dphi_dx, dphi_dy = self.off.forward(self.L_data, n_sigma, phi=True, dphi_dx=True, dphi_dy=True)
        ux, uy = model(x, y, phi)
        data_loss = F.mse_loss(torch.cat((ux,uy),dim=-1).squeeze(), self.U_data)
        return data_loss

    def PDE_loss(self,label):

        x, y, dphi_dx, dphi_dy, d2phi_dx2, d2phi_dy2 = self.off.forward(label, n_sigma, dphi_dx=True, dphi_dy=True, d2phi_dx2=True, d2phi_dy2=True)
        x.requires_grad = True
        y.requires_grad = True
        sigma_xx, sigma_xy, sigma_yx, sigma_yy, px, py = self.model.Fsigma(x,y,dphi_dx,dphi_dy)

        dsigmaxx_dx = derivee(sigma_xx,x) + som(px * d2phi_dx2)
        dsigmaxy_dy = derivee(sigma_xy,y) + som(px * d2phi_dy2)
        dsigmayx_dx = derivee(sigma_yx,x) + som(py * d2phi_dx2)
        dsigmayy_dy = derivee(sigma_yy,y) + som(py * d2phi_dy2)

        pde_x = dsigmaxx_dx + dsigmaxy_dy
        pde_y = dsigmayx_dx + dsigmayy_dy

        pde_loss_x = F.mse_loss(pde_x, torch.zeros_like(pde_x))
        pde_loss_y = F.mse_loss(pde_y, torch.zeros_like(pde_y))

        return pde_loss_x + pde_loss_y

    def C_loss(self,label):

        x, y, phi, dphi_dx, dphi_dy = self.off.forward(label, n_u, phi=True, dphi_dx=True, dphi_dy=True)
        x.requires_grad = True
        y.requires_grad = True
        phi.requires_grad = True

        ux, uy = self.model(x,y,phi)

        epsilon_xx = derivee(ux,x) + som(derivee(ux,phi) * dphi_dx)
        epsilon_xy = derivee(ux,y) + som(derivee(ux,phi) * dphi_dy)
        epsilon_yx = derivee(uy,x) + som(derivee(uy,phi) * dphi_dx)
        epsilon_yy = derivee(uy,y) + som(derivee(uy,phi) * dphi_dy)

        sigma_xx0 = self.c1*epsilon_xx + self.c2*epsilon_yy
        sigma_xy0 = self.c3*epsilon_xy + self.c3*epsilon_yx
        sigma_yx0 = self.c3*epsilon_xy + self.c3*epsilon_yx
        sigma_yy0 = self.c2*epsilon_xx + self.c1*epsilon_yy

        x, y, phi, dphi_dx, dphi_dy = self.off.forward(label, n_sigma, phi=True, dphi_dx=True, dphi_dy=True)
        sigma_xx, sigma_xy, sigma_yx, sigma_yy, H1, H2 = self.model.Fsigma(x,y,dphi_dx,dphi_dy)

        loss_C = F.mse_loss(torch.cat((sigma_xx0,sigma_xy0,sigma_yx0,sigma_yy0),dim=-1), \
                    torch.cat((sigma_xx,sigma_xy,sigma_yx,sigma_yy),dim=-1))

        return loss_C

# %%
class MLP_gelu(nn.Module):
    def __init__(self,insize,outsize,width,layers):
        super().__init__()
        self.input_layer = nn.Linear(insize,width)
        self.hidden_layers = nn.ModuleList([])
        self.output_layer = nn.Linear(width,outsize)
        for i in range(layers):
          self.linear_layer = nn.Linear(width,width)
          self.hidden_layers.append(self.linear_layer)
        self.layers = layers

    def forward(self, x): # F.gelu
        layer_out = F.gelu(self.input_layer(x))
        for i in range(self.layers):
            layer_out = F.gelu(self.hidden_layers[i](layer_out))
        layer_out = self.output_layer(layer_out)
        return layer_out

class Finite_PINN(nn.Module):
    def __init__(self, n_sigma, n_u):
        super(Finite_PINN, self).__init__()

        width = 128
        self.NN_H1 = MLP_gelu(2,n_sigma,width,4)
        self.NN_H2 = MLP_gelu(2,n_sigma,width,4)
        self.NN_eu1 = MLP_gelu(2+n_u,1,width,4)
        self.NN_eu2 = MLP_gelu(2+n_u,1,width,4)

    def forward(self, x, y, u):

        v1 = self.NN_eu1(torch.cat((x,y,u),dim=-1))
        v2 = self.NN_eu2(torch.cat((x,y,u),dim=-1))

        return v1,v2

    def Fsigma(self, x, y, du_dx, du_dy):

        px = self.NN_H1(torch.cat((x,y),dim=-1))
        py = self.NN_H2(torch.cat((x,y),dim=-1))

        sig_xx, sig_xy = som(px * du_dx), som(px * du_dy)
        sig_yx, sig_yy = som(py * du_dx), som(py * du_dy)

        return sig_xx,sig_xy,sig_yx,sig_yy,px,py

# %%
n_sigma = 4
n_u = 4

OFF = Offline(path)
model = Finite_PINN(n_sigma = n_sigma, n_u = n_u).to(device, dtype = torch.float32)
ON = Online(path,OFF,model)

L_pde = ON.label_pde()
dataset = torch.utils.data.TensorDataset(L_pde,torch.zeros_like(L_pde))
trainset = torch.utils.data.DataLoader(dataset, batch_size=200, shuffle=True, drop_last=True)

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
num_epochs = 1000
csize = 4

for ep in range(num_epochs):
    model.train()
    t1 = default_timer()
    d_mse,pde_mse,c_mse = 0,0,0
    ne = 0

    for l_pde, r_pde in trainset:

        ne += 1
        optimizer.zero_grad()

        # Data Loss
        data_loss = ON.Data_loss()
        # PDE Loss
        pde_loss = ON.PDE_loss(l_pde)
        # Constitutive loss
        C_loss = ON.C_loss(l_pde)

        Loss = data_loss + pde_loss + C_loss

        Loss.backward()
        optimizer.step()

        d_mse += data_loss.item()
        pde_mse += pde_loss.item()
        c_mse += C_loss.item()

    bc_mse /= ne
    pde_mse /= ne
    c_mse /= ne

    t2 = default_timer()

    print(f'Epoch:{ep+1}, Time:{t2-t1:.3g}s, Data Loss:{data_loss:.3e}, PDE Loss:{pde_mse:.3e}, C Loss:{c_mse:.3e}')
# Out:
# Epoch:1, Time:1.47s, Data Loss:3.985e-01, PDE Loss:3.183e-03, C Loss:1.214e-04
# Epoch:2, Time:1.29s, Data Loss:2.802e-01, PDE Loss:6.307e-05, C Loss:2.833e-03
# Epoch:3, Time:1.35s, Data Loss:1.399e-01, PDE Loss:1.523e-04, C Loss:1.337e-02
# Epoch:4, Time:1.33s, Data Loss:8.381e-02, PDE Loss:3.182e-04, C Loss:3.485e-02
# Epoch:5, Time:1.37s, Data Loss:7.076e-02, PDE Loss:4.320e-04, C Loss:3.027e-02
# Epoch:6, Time:1.4s, Data Loss:5.495e-02, PDE Loss:5.998e-04, C Loss:2.787e-02
# Epoch:7, Time:1.3s, Data Loss:3.840e-02, PDE Loss:8.815e-04, C Loss:3.008e-02
# Epoch:8, Time:1.25s, Data Loss:2.953e-02, PDE Loss:1.237e-03, C Loss:3.320e-02
# Epoch:9, Time:1.27s, Data Loss:2.784e-02, PDE Loss:1.386e-03, C Loss:3.429e-02
# Epoch:10, Time:1.24s, Data Loss:2.393e-02, PDE Loss:1.469e-03, C Loss:3.359e-02
# Epoch:11, Time:1.35s, Data Loss:2.291e-02, PDE Loss:1.546e-03, C Loss:3.262e-02
# Epoch:12, Time:1.3s, Data Loss:2.015e-02, PDE Loss:1.647e-03, C Loss:3.168e-02
# Epoch:13, Time:1.26s, Data Loss:1.760e-02, PDE Loss:1.788e-03, C Loss:3.019e-02
# Epoch:14, Time:1.29s, Data Loss:1.585e-02, PDE Loss:1.946e-03, C Loss:2.890e-02
# Epoch:15, Time:1.22s, Data Loss:1.462e-02, PDE Loss:2.321e-03, C Loss:2.686e-02
# Epoch:16, Time:1.28s, Data Loss:1.162e-02, PDE Loss:2.901e-03, C Loss:2.536e-02
# Epoch:17, Time:1.44s, Data Loss:9.835e-03, PDE Loss:2.881e-03, C Loss:2.459e-02
# Epoch:18, Time:1.25s, Data Loss:9.123e-03, PDE Loss:3.200e-03, C Loss:2.363e-02
# Epoch:19, Time:1.38s, Data Loss:9.498e-03, PDE Loss:3.354e-03, C Loss:2.264e-02
# Epoch:20, Time:1.5s, Data Loss:6.913e-03, PDE Loss:3.510e-03, C Loss:2.155e-02
# Epoch:21, Time:1.45s, Data Loss:6.330e-03, PDE Loss:3.512e-03, C Loss:2.034e-02
# Epoch:22, Time:1.44s, Data Loss:6.174e-03, PDE Loss:3.675e-03, C Loss:1.919e-02
# Epoch:23, Time:1.32s, Data Loss:6.136e-03, PDE Loss:3.549e-03, C Loss:1.823e-02
# Epoch:24, Time:1.34s, Data Loss:4.894e-03, PDE Loss:3.686e-03, C Loss:1.752e-02
# Epoch:25, Time:1.34s, Data Loss:5.696e-03, PDE Loss:3.522e-03, C Loss:1.732e-02
# Epoch:26, Time:1.36s, Data Loss:4.689e-03, PDE Loss:3.579e-03, C Loss:1.695e-02
# Epoch:27, Time:1.5s, Data Loss:5.265e-03, PDE Loss:3.459e-03, C Loss:1.665e-02
# Epoch:28, Time:1.43s, Data Loss:3.926e-03, PDE Loss:3.396e-03, C Loss:1.638e-02
# Epoch:29, Time:1.39s, Data Loss:4.839e-03, PDE Loss:3.533e-03, C Loss:1.603e-02
# Epoch:30, Time:1.4s, Data Loss:3.935e-03, PDE Loss:3.412e-03, C Loss:1.572e-02
# Epoch:31, Time:1.37s, Data Loss:3.971e-03, PDE Loss:3.374e-03, C Loss:1.541e-02
# Epoch:32, Time:1.33s, Data Loss:4.819e-03, PDE Loss:3.498e-03, C Loss:1.512e-02
# Epoch:33, Time:1.33s, Data Loss:3.919e-03, PDE Loss:3.453e-03, C Loss:1.487e-02
# Epoch:34, Time:1.3s, Data Loss:4.344e-03, PDE Loss:3.288e-03, C Loss:1.466e-02
# Epoch:35, Time:1.38s, Data Loss:3.992e-03, PDE Loss:3.321e-03, C Loss:1.432e-02
# Epoch:36, Time:1.37s, Data Loss:3.693e-03, PDE Loss:3.382e-03, C Loss:1.410e-02
# Epoch:37, Time:1.28s, Data Loss:3.097e-03, PDE Loss:3.434e-03, C Loss:1.374e-02
# Epoch:38, Time:1.3s, Data Loss:2.977e-03, PDE Loss:3.456e-03, C Loss:1.354e-02
# Epoch:39, Time:1.31s, Data Loss:3.432e-03, PDE Loss:3.403e-03, C Loss:1.333e-02
# Epoch:40, Time:1.25s, Data Loss:2.915e-03, PDE Loss:3.439e-03, C Loss:1.325e-02
# Epoch:41, Time:1.33s, Data Loss:3.621e-03, PDE Loss:3.376e-03, C Loss:1.313e-02
# Epoch:42, Time:1.3s, Data Loss:2.999e-03, PDE Loss:3.473e-03, C Loss:1.291e-02
# Epoch:43, Time:1.23s, Data Loss:2.965e-03, PDE Loss:3.526e-03, C Loss:1.267e-02
# Epoch:44, Time:1.28s, Data Loss:2.842e-03, PDE Loss:3.594e-03, C Loss:1.266e-02
# Epoch:45, Time:1.34s, Data Loss:2.641e-03, PDE Loss:3.509e-03, C Loss:1.251e-02
# Epoch:46, Time:1.34s, Data Loss:2.557e-03, PDE Loss:3.539e-03, C Loss:1.230e-02
# Epoch:47, Time:1.26s, Data Loss:2.413e-03, PDE Loss:3.605e-03, C Loss:1.216e-02
# Epoch:48, Time:1.24s, Data Loss:2.926e-03, PDE Loss:3.432e-03, C Loss:1.217e-02
# Epoch:49, Time:1.27s, Data Loss:2.596e-03, PDE Loss:3.497e-03, C Loss:1.197e-02
# Epoch:50, Time:1.33s, Data Loss:2.575e-03, PDE Loss:3.578e-03, C Loss:1.188e-02
# Epoch:51, Time:1.42s, Data Loss:2.684e-03, PDE Loss:3.455e-03, C Loss:1.171e-02
# Epoch:52, Time:1.44s, Data Loss:2.711e-03, PDE Loss:3.622e-03, C Loss:1.159e-02
# Epoch:53, Time:1.39s, Data Loss:2.824e-03, PDE Loss:3.576e-03, C Loss:1.146e-02
# Epoch:54, Time:1.43s, Data Loss:2.201e-03, PDE Loss:3.643e-03, C Loss:1.133e-02
# Epoch:55, Time:1.42s, Data Loss:2.639e-03, PDE Loss:3.526e-03, C Loss:1.127e-02
# Epoch:56, Time:1.36s, Data Loss:2.082e-03, PDE Loss:3.548e-03, C Loss:1.115e-02
# Epoch:57, Time:1.46s, Data Loss:2.291e-03, PDE Loss:3.538e-03, C Loss:1.103e-02
# Epoch:58, Time:1.41s, Data Loss:2.707e-03, PDE Loss:3.533e-03, C Loss:1.087e-02
# Epoch:59, Time:1.26s, Data Loss:1.909e-03, PDE Loss:3.515e-03, C Loss:1.071e-02
# Epoch:60, Time:1.27s, Data Loss:2.587e-03, PDE Loss:3.456e-03, C Loss:1.065e-02
# Epoch:61, Time:1.42s, Data Loss:2.350e-03, PDE Loss:3.598e-03, C Loss:1.046e-02
# Epoch:62, Time:1.24s, Data Loss:2.703e-03, PDE Loss:3.561e-03, C Loss:1.049e-02
# Epoch:63, Time:1.32s, Data Loss:2.207e-03, PDE Loss:3.630e-03, C Loss:1.022e-02
# Epoch:64, Time:1.34s, Data Loss:1.708e-03, PDE Loss:3.569e-03, C Loss:1.007e-02
# Epoch:65, Time:1.35s, Data Loss:2.084e-03, PDE Loss:3.517e-03, C Loss:1.031e-02
# Epoch:66, Time:1.27s, Data Loss:1.690e-03, PDE Loss:3.582e-03, C Loss:9.977e-03
# Epoch:67, Time:1.26s, Data Loss:2.028e-03, PDE Loss:3.540e-03, C Loss:1.006e-02
# Epoch:68, Time:1.24s, Data Loss:2.170e-03, PDE Loss:3.489e-03, C Loss:9.944e-03
# Epoch:69, Time:1.28s, Data Loss:1.983e-03, PDE Loss:3.559e-03, C Loss:9.848e-03
# Epoch:70, Time:1.28s, Data Loss:1.996e-03, PDE Loss:3.626e-03, C Loss:9.788e-03
# Epoch:71, Time:1.34s, Data Loss:1.845e-03, PDE Loss:3.569e-03, C Loss:9.718e-03
# Epoch:72, Time:1.34s, Data Loss:2.156e-03, PDE Loss:3.637e-03, C Loss:9.784e-03
# Epoch:73, Time:1.35s, Data Loss:2.057e-03, PDE Loss:3.470e-03, C Loss:9.664e-03
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 21
#      19 pde_loss = ON.PDE_loss(l_pde)
#      20 # Constitutive loss
# ---> 21 C_loss = ON.C_loss(l_pde)
#      23 Loss = data_loss  + pde_loss + C_loss
#      25 Loss.backward()
#
# Cell In[33], line 54, in Online.C_loss(self, label)
#      51 y.requires_grad = True
#      52 phi.requires_grad = True
# ---> 54 ux, uy = self.model(x,y,phi)
#      56 epsilon_xx = derivee(ux,x) + som(derivee(ux,phi) * dphi_dx)
#      57 epsilon_xy = derivee(ux,y) + som(derivee(ux,phi) * dphi_dy)
#
# File ~\.conda\envs\torch_env\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\.conda\envs\torch_env\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# Cell In[34], line 32, in Finite_PINN.forward(self, x, y, u)
#      29 def forward(self, x, y, u):
#      31     v1 = self.NN_eu1(torch.cat((x,y,u),dim=-1))
# ---> 32     v2 = self.NN_eu2(torch.cat((x,y,u),dim=-1))
#      34     return v1,v2
#
# File ~\.conda\envs\torch_env\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\.conda\envs\torch_env\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# Cell In[34], line 15, in MLP_gelu.forward(self, x)
#      13 layer_out = F.gelu(self.input_layer(x))
#      14 for i in range(self.layers):
# ---> 15     layer_out = F.gelu(self.hidden_layers[i](layer_out))
#      16 layer_out = self.output_layer(layer_out)
#      17 return layer_out
#
# KeyboardInterrupt:

# %%
model.eval()
X_plot, Y_plot, Phi_plot = OFF.X, OFF.Y, OFF.Phi[:,:n_u]
vx_plot, vy_plot = model(OFF.X, OFF.Y, OFF.Phi[:,:n_u])
vx_plot = vx_plot.squeeze().squeeze().detach().cpu()
vy_plot = vy_plot.squeeze().squeeze().detach().cpu()
plt.figure(figsize=(6, 5))
plt.subplot(2, 2, 1)
plt.scatter(X_plot.squeeze().detach().cpu(), Y_plot.squeeze().detach().cpu(), c=vx_plot, s = 1.5, cmap='jet')
plt.title('Ux')
plt.axis('equal')
plt.axis('off')
plt.colorbar(fraction=0.046, pad=0.04)
plt.subplot(2, 2, 2)
plt.scatter(X_plot.squeeze().detach().cpu(), Y_plot.squeeze().detach().cpu(), c=vy_plot, s = 1.5, cmap='jet')
plt.title('Uy')
plt.axis('equal')
plt.axis('off')
plt.colorbar(fraction=0.046, pad=0.04)
plt.savefig('square.png')
plt.tight_layout()
plt.show()
